# %% [markdown]
# # Converting LP files to quadratic optimization objects
#
# To obtain the bounds which will be benchmarked against the classical solution, we will use the utilities from the LP parser provided from the starter code.

# %%
from ..src import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from ..src import *
#       2 from ..src.sbo.src.utils.lp_parser import LPParser
#
# ImportError: attempted relative import with no known parent package
